# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

# %%
df =pd.read_csv('/content/first inten project.csv')

# %%
df.head()
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price   \
# ...

# %%
df
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
#add column
df['number of resdience'] = df['number of adults'] + df['number of children']

# %%
df.head()
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price   \
# ...

# %%
df.columns
# Out:
# Index(['Booking_ID', 'number of adults', 'number of children',
#        'number of weekend nights', 'number of week nights', 'type of meal',
#        'car parking space', 'room type', 'lead time', 'market segment type',
#        'repeated', 'P-C', 'P-not-C', 'average price ', 'special requests',
#        'date of reservation', 'booking status', 'number of resdience'],
#       dtype='object')

# %%
#drop the new column
df.drop('number of resdience', axis=1, inplace=True)
df
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
df.describe()
#show the statistics information
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
df.info()
#to know the info and the type of data in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
df.max()
# Out:
# Booking_ID                      INN36286
# number of adults                       4
# number of children                    10
# number of weekend nights               7
# number of week nights                 17
# type of meal                Not Selected
# car parking space                      1
# room type                    Room_Type 7
# lead time                            443
# market segment type               Online
# repeated                               1
# P-C                                   13
# P-not-C                               58
# average price                      540.0
# special requests                       5
# date of reservation             9/9/2018
# booking status              Not_Canceled
# dtype: object

# %%
df.sum()
# Out:
# Booking_ID                  INN00001INN00002INN00003INN00004INN00005INN000...
# number of adults                                                        66940
# number of children                                                       3823
# number of weekend nights                                                29416
# number of week nights                                                   79994
# type of meal                Meal Plan 1Not SelectedMeal Plan 1Meal Plan 1N...
# car parking space                                                        1124
# room type                   Room_Type 1Room_Type 1Room_Type 1Room_Type 1Ro...
# lead time                                                             3092928
# market segment type         OfflineOnlineOnlineOnlineOnlineOfflineOnlineOn...
# repeated                                                                  930
# P-C                                                                       847
# ...

# %%
df.sort_values(by='number of adults', ascending=False)
#removing ascending= false or replace it with true to be ascending
# Out:
#       Booking_ID  number of adults  number of children  \
# 23526   INN23527                 4                   0
# 657     INN00658                 4                   0
# 3153    INN03154                 4                   0
# 30321   INN30322                 4                   0
# 15220   INN15221                 4                   0
# ...          ...               ...                 ...
# 32816   INN32817                 0                   2
# 2643    INN02644                 0                   2
# 25908   INN25909                 0                   2
# 2527    INN02528                 0                   2
# 28782   INN28783                 0                   2
#
#        number of weekend nights  number of week nights type of meal  \
# 23526                         0                      1  Meal Plan 1
# 657                           0                      2  Meal Plan 1
# 3153                          0                      3  Meal Plan 1
# ...

# %%
df.shape
#(columns, row)
# Out:
# (36285, 17)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36280    False
# 36281    False
# 36282    False
# 36283    False
# 36284    False
# Length: 36285, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.duplicated(subset=['Booking_ID'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36280    False
# 36281    False
# 36282    False
# 36283    False
# 36284    False
# Length: 36285, dtype: bool

# %%
sum(df.duplicated(subset=['Booking_ID']))
# Out:
# 0

# %%
sum(df.duplicated(subset=['Booking_ID']))==0
# Out:
# True

# %%
df.isna().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
df['Booking_ID'].dropna()
# Out:
# 0        INN00001
# 1        INN00002
# 2        INN00003
# 3        INN00004
# 4        INN00005
#            ...
# 36280    INN36282
# 36281    INN36283
# 36282    INN36284
# 36283    INN36285
# 36284    INN36286
# Name: Booking_ID, Length: 36285, dtype: object

# %%
# to fill null you can use the mode, mean and median
# df[' the column].filna('_____')

# %%
df['type of meal'].unique()
# Out:
# array(['Meal Plan 1', 'Not Selected', 'Meal Plan 2', 'Meal Plan 3'],
#       dtype=object)

# %%
#df['type of meal'] = df['type of meal'].replace("Meal Plan 1",1)
#df['type of meal'] = df['type of meal'].replace("Meal Plan 2",2)
#df['type of meal'] = df['type of meal'].replace("Meal Plan 3",3)
#df['type of meal'] = df['type of meal'].replace("Not Selected",0)

#df['type of meal']

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['type of meal']= label_encoder.fit_transform(df['type of meal'])

df['type of meal'].unique()
# Out:
# array([0, 3, 1, 2])

# %%
df['type of meal']
# Out:
# 0        0
# 1        3
# 2        0
# 3        0
# 4        3
#         ..
# 36280    1
# 36281    0
# 36282    0
# 36283    0
# 36284    0
# Name: type of meal, Length: 36285, dtype: int64

# %%
df = df.drop(('type of meal'),axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   car parking space         36285 non-null  int64
#  6   room type                 36285 non-null  object
#  7   lead time                 36285 non-null  int64
#  8   market segment type       36285 non-null  object
#  9   repeated                  36285 non-null  int64
#  10  P-C                       36285 non-null  int64
#  11  P-not-C                   36285 non-null  int64
#  12  average price             36285 non-null  float64
#  13  special requests          36285 non-null  int64
# ...

# %%
sns.boxplot( df=df['number of adults'],palette='rainbow',orient='h')
#box plot to show outliers
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py:1601: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# <Axes: >

# %%
x =df['number of adults']
y =df['average price ']

# %%
plt.plot(x, y,'r')
plt.xlabel('number of adults')
plt.ylabel('average price')
plt.title('number of adults vs average price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df['average price '],kde = False)
#to plt column with its density
# pass kde = false as parameter if you want histogram only
# Out:
# <ipython-input-72-9cb05602df5a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['average price '],kde = False)
# <Axes: xlabel='average price '>

# %%
sns.distplot(df['average price '])
#pass kde = true that will show normal distribution and histogram
# Out:
# <ipython-input-73-c445abc18fc1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['average price '])
# <Axes: xlabel='average price ', ylabel='Density'>

# %%
sns.jointplot(x='number of adults',y='average price ',data=df,kind='scatter')

# %%
sns.jointplot(x='number of adults',y='average price ',data=df,kind='hex')

# %%
sns.pairplot(df)
# pass all the data and do all the possible compination

# %%
sns.pairplot(df,hue='number of children',palette='coolwarm')
#pair plot relations with column

# %%
sns.barplot(x='number of adults',y='average price ',data=df)
#bar plot (density)
# Out:
# <Axes: xlabel='number of adults', ylabel='average price '>

# %%
sns.countplot(x='number of adults',data=df)
#count plot
# Out:
# <Axes: xlabel='number of adults', ylabel='count'>

# %%
sns.boxplot(data=df,palette='rainbow',orient='h')
#box plot to show outliers
