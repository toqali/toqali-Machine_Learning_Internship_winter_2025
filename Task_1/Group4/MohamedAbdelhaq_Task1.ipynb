# %% [markdown]
# # Task 1

# %% [markdown]
# ## A) Preparations

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv(r"e:\Courses\Cellula\first inten project.csv")

# %% [markdown]
# ## B) Understand the Data

# %%
data # show data
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
data.info() # columns datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
# Know unique strings to deepen the understanding
unique_values = data["market segment type"].value_counts()
print(f"market segment type are {unique_values}")
print("*************************************************************************")

unique_values = data["booking status"].value_counts()
print(f"booking status types are {unique_values}")
print("*************************************************************************")
# Out:
# market segment type are market segment type
# Online           23221
# Offline          10531
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: count, dtype: int64
# *************************************************************************
# booking status types are booking status
# Not_Canceled    24396
# Canceled        11889
# Name: count, dtype: int64
# *************************************************************************

# %%
# Know unique strings to deepen the understanding
unique_values = data["type of meal"].value_counts()
print(f"Meal values are {unique_values}")
print("*************************************************************************")

unique_values = data["room type"].value_counts()
print(f"Room types are {unique_values}")
print("*************************************************************************")
# Out:
# Meal values are type of meal
# Meal Plan 1     27842
# Not Selected     5132
# Meal Plan 2      3306
# Meal Plan 3         5
# Name: count, dtype: int64
# *************************************************************************
# Room types are room type
# Room_Type 1    28138
# Room_Type 4     6059
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: count, dtype: int64
# *************************************************************************

# %% [markdown]
# ## C) Data Checking

# %%
data.isnull().sum()  # Check missing values
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
sum(data.duplicated())   # check count of duplicated rows
# data[data.duplicated()] → Display duplicated rows
# Out:
# 0

# %%
data.isnull().mean() * 100   # % of missing data
# Out:
# Booking_ID                  0.0
# number of adults            0.0
# number of children          0.0
# number of weekend nights    0.0
# number of week nights       0.0
# type of meal                0.0
# car parking space           0.0
# room type                   0.0
# lead time                   0.0
# market segment type         0.0
# repeated                    0.0
# P-C                         0.0
# P-not-C                     0.0
# average price               0.0
# special requests            0.0
# date of reservation         0.0
# booking status              0.0
# dtype: float64

# %%
# data[data["lead time"] < 0]  
# data[data["average price "] < 0] 
# data[data["number of children"] < 0] 
# data[data["number of adults"] < 0] 
# data[data["special requests"] < 0] 
# data[data["number of weekend nights"] < 0] 
# data[data["number of week nights"] < 0] 
# data[data["P-C"] < 0] 
# data[data["P-not-C"] < 0] 

(data.select_dtypes(include=['number']) < 0).sum()  # show how many negative values exist per column.
# Out:
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# car parking space           0
# lead time                   0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# dtype: int64

# %% [markdown]
# ## D) Describtion & Modification

# %%
data.describe() #  AT first to explore numeric features
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
# Select numerical columns
numerical_columns = data.select_dtypes(include=['number']).columns

# Define number of rows and columns for subplots
num_cols = len(numerical_columns)
num_rows = (num_cols // 3) + (num_cols % 3 > 0)  # Arrange in rows of 3

# Create subplots
fig, axes = plt.subplots(num_rows, 3, figsize=(15, 5 * num_rows))
axes = axes.flatten()  # Flatten axes array for easy iteration

# Plot each numerical column
for i, col in enumerate(numerical_columns):
    sns.boxplot(x=data[col], ax=axes[i])
    axes[i].set_title(f"Boxplot for {col}")

# Remove empty subplots if any
for i in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
## get copy of the dataset to avoid any problems on the real dataset
df_copy = data.copy()

# %%
## loop through all columns, check if its a number, then calculate IQR
for col in df_copy.columns:
    if df_copy[col].dtype in ['int64', 'float64']:  # Check if the column is numeric
        # Calculate Q1, Q3, and IQR
        Q1 = df_copy[col].quantile(0.25)
        Q3 = df_copy[col].quantile(0.75)
        IQR = Q3 - Q1

        # Define outlier bounds
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Calculate the mode
        mode_value = df_copy[col].mode()

        # Replace outliers with the mode
        df_copy[col] = np.where((df_copy[col] < lower_bound) | (df_copy[col] > upper_bound), mode_value, df_copy[col])

# %%
# Select numerical columns
numerical_columns = df_copy.select_dtypes(include=['number']).columns

# Define number of rows and columns for subplots
num_cols = len(numerical_columns)
num_rows = (num_cols // 3) + (num_cols % 3 > 0)  # Arrange in rows of 3

# Create subplots
fig, axes = plt.subplots(num_rows, 3, figsize=(15, 5 * num_rows))
axes = axes.flatten()  # Flatten axes array for easy iteration

# Plot each numerical column
for i, col in enumerate(numerical_columns):
    sns.boxplot(x=df_copy[col], ax=axes[i])
    axes[i].set_title(f"Boxplot for {col}")

# Remove empty subplots if any
for i in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## E) Relations

# %%
# Compute correlation matrix
corr_matrix = data.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap before Outliers")
plt.show()

# %%
# Compute correlation matrix
corr_matrix = df_copy.corr(numeric_only=True)   

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap after Outliers")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set a consistent style
sns.set_style("whitegrid")

# Ensure column names are correctly formatted
df_copy.columns = df_copy.columns.str.strip().str.lower().str.replace(" ", "_")

# Create subplots
fig, axes = plt.subplots(4, 2, figsize=(16, 14))

# -------------------- 1️⃣ Booking Status & Lead Time --------------------
sns.boxplot(x="booking_status", y="lead_time", data=df_copy, ax=axes[0, 0])
axes[0, 0].set_title("Lead Time vs Booking Status")

sns.kdeplot(data=df_copy, x="lead_time", hue="booking_status", common_norm=False, ax=axes[0, 1])
axes[0, 1].set_title("Lead Time Distribution by Booking Status")

# -------------------- 2️⃣ Booking Status & Average Price --------------------
sns.violinplot(x="booking_status", y="average_price", data=df_copy, ax=axes[1, 0])
axes[1, 0].set_title("Average Price vs Booking Status")

# -------------------- 3️⃣ Booking Status & Number of Adults --------------------
sns.countplot(x="number_of_adults", hue="booking_status", data=df_copy, ax=axes[1, 1])
axes[1, 1].set_title("Number of Adults vs Booking Status")

# -------------------- 4️⃣ Booking Status & Number of Children --------------------
child_status = df_copy.groupby(["number_of_children", "booking_status"]).size().unstack(fill_value=0)
child_status.plot(kind="bar", stacked=True, ax=axes[2, 0])
axes[2, 0].set_title("Number of Children vs Booking Status")
axes[2, 0].set_xlabel("Number of Children")
axes[2, 0].set_ylabel("Count")

# -------------------- 5️⃣ Booking Status & Special Requests --------------------
request_status = df_copy.groupby(["special_requests", "booking_status"]).size().unstack(fill_value=0)
request_status.plot(kind="bar", stacked=True, ax=axes[2, 1])
axes[2, 1].set_title("Special Requests vs Booking Status")
axes[2, 1].set_xlabel("Number of Special Requests")
axes[2, 1].set_ylabel("Count")

# -------------------- 6️⃣ Booking Status & Number of Weekend Nights --------------------
sns.boxplot(x="booking_status", y="number_of_weekend_nights", data=df_copy, ax=axes[3, 0])
axes[3, 0].set_title("Weekend Nights vs Booking Status")

# -------------------- 7️⃣ Booking Status & Number of Week Nights --------------------
sns.boxplot(x="booking_status", y="number_of_week_nights", data=df_copy, ax=axes[3, 1])
axes[3, 1].set_title("Week Nights vs Booking Status")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Ensure column names are formatted correctly
df_copy.columns = df_copy.columns.str.strip().str.lower().str.replace(" ", "_")

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# -------------------- 1️⃣ Booking Status & Type of Meal --------------------
sns.countplot(x="type_of_meal", hue="booking_status", data=df_copy, ax=axes[0])
axes[0].set_title("Type of Meal vs Booking Status")
axes[0].set_xlabel("Type of Meal")
axes[0].set_ylabel("Count")
axes[0].tick_params(axis='x', rotation=45)

# -------------------- 2️⃣ Booking Status & Room Type --------------------
sns.countplot(x="room_type", hue="booking_status", data=df_copy, ax=axes[1])
axes[1].set_title("Room Type vs Booking Status")
axes[1].set_xlabel("Room Type")
axes[1].set_ylabel("Count")
axes[1].tick_params(axis='x', rotation=45)

# -------------------- 3️⃣ Booking Status & Market Segment Type --------------------
sns.countplot(x="market_segment_type", hue="booking_status", data=df_copy, ax=axes[2])
axes[2].set_title("Market Segment Type vs Booking Status")
axes[2].set_xlabel("Market Segment Type")
axes[2].set_ylabel("Count")
axes[2].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Convert year_month to string for readability
df_copy["year_month"] = df_copy["year_month"].astype(str)

# Create a pivot table for the heatmap
heatmap_data = df_copy.pivot_table(index="year_month", columns="booking_status", aggfunc="size", fill_value=0)

# Calculate cancellation percentage
heatmap_data["Cancellation_Percentage"] = (heatmap_data.get("Canceled", 0) / heatmap_data.sum(axis=1)) * 100

# Display first few rows to check the result
print(heatmap_data.head())
# Out:
# booking_status  Canceled  Not_Canceled  Cancellation_Percentage
# year_month
# 2015-10                0             1                 0.000000
# 2016-09                1             0               100.000000
# 2017-05                1             0               100.000000
# 2017-07              243           120                66.942149
# 2017-08              185           829                18.244576

# %%
import seaborn as sns

# Convert period to string for better readability in the heatmap
df_copy["year_month"] = df_copy["year_month"].astype(str)

# Create a pivot table
heatmap_data = df_copy.pivot_table(index="year_month", columns="booking_status", aggfunc="size", fill_value=0)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap="YlGnBu", annot=True, fmt="d", linewidths=0.5)
plt.title("Heatmap of Booking Status Over Time")
plt.xlabel("Booking Status")
plt.ylabel("Year-Month")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
data['repeated'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='coolwarm')
plt.title("Percentage of Regular Customers vs New Customers")
plt.ylabel("")
plt.legend(title='Regular Customer', labels=['No', 'Yes'], loc='upper left')
plt.show()
